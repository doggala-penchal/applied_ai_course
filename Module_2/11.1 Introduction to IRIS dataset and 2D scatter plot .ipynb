# %%
# One dimentional vector is called Scalar.[0] or [1], etc
# all vectors other than scalars are called Vectors. [1, 2, 3, 4, 5]
# Every observation in data set is called observation or certain dimension vector. [0,1,2,3,4,5]
# First gain domain knowledge so that you can get clear intuition about the problem.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sea

# %%
x = np.array([1,2,3,4,5])
y = np.array([6,7,8,9,10])
plt.plot(x, y, 'ro')
plt.show()

# %%
data = pd.read_csv('iris.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.shape
# Out:
# (150, 5)

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data['species'].value_counts() # .value_counts() gives different values in that column
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
plt.scatter(data['sepal_length'], data['sepal_width'])
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.title('sepal_length vs sepal_width')
# Out:
# Text(0.5, 1.0, 'sepal_length vs sepal_width')

# %%
sea.set_style('whitegrid')
sea.FacetGrid(data, hue= 'species', size = 5).map(plt.scatter, 'sepal_length', 'sepal_width').add_legend()

plt.show()

# %%
# There are 2 types of data_sets
# 1)Balanced_data_Set
# 2)Imbalaced data_Set

# For imbalanced dataset we have to do slightly different data analysis than balanced dataset

# %%
plt.close
sea.set_style('whitegrid')
sea.pairplot(data, hue= 'species', size= 4)
plt.show()

# %%
print(data['species'].value_counts())
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
iris_setosa = data.loc[data['species'] == 'setosa']
iris_versicolor = data.loc[data['species'] == 'versicolor']
iris_virginica = data.loc[data['species'] == 'virginica']
plt.plot(iris_setosa['petal_length'], np.zeros_like(iris_setosa['petal_width']))
plt.plot(iris_versicolor['petal_length'], np.zeros_like(iris_versicolor['petal_width']))
plt.plot(iris_virginica['petal_length'], np.zeros_like(iris_virginica['petal_width']))

# %%
a = [[1,2,3], [4,5,6]]
print(np.zeros_like(a))
# Out:
# [[0 0 0]
#  [0 0 0]]

# %%
np.zeros([2,3], dtype = int)
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...
